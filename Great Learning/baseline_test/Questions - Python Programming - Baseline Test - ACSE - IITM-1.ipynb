# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1tpOCamr9aWz817atPnyXus8w5gJ3mIts" width=500px>
#
# Proprietary content. © Great Learning. All Rights Reserved. Unauthorized use or distribution prohibited.

# %% [markdown]
# ---
# # Baseline Test - Advanced Certificate in Software Engineering - IIT Madras
# ---

# %% [markdown]
# # Instructions
#
# - Some parts of the code are already done for you
# - You need to add the code where ever you see "`#### Add your code here ####`"
# - Marks are mentioned along with the cells
# - **Do not edit any of the prefilled text/code part**

# %% [markdown]
# ## Question 1 (10 Marks)

# %% [markdown]
# Write a function to remove duplicate elements from the given list.
#
# `A =  [2, 5, 7, 3, 33, 3, 5, 7]`
#
# ***
# #### Sample Input/Output:
# ---
# - Input: `A =  [2, 5, 7, 3, 33, 3, 5, 7]`
# - Output: `Updated list after removing duplicate elements: [2, 5, 7, 3, 33]`
# ---

# %%
A = [2, 5, 7, 3, 33, 3, 5, 7]

def remove(A): 
    temp_list = [] 
    #### Add your code here ####
    duplicates = []
    for i in A:
        if(i in temp_list):
            duplicates.append(i)
        else:
            temp_list.append(i)

    return temp_list
      
print("Updated list after removing duplicate elements: ", remove(A))
# Out:
# Updated list after removing duplicate elements:  [2, 5, 7, 3, 33]

# %% [markdown]
# ## Question 2 (15 Marks)

# %% [markdown]
# Write a program that takes input from the user to enter a string (consisting of any characters). Then create and print a dictionary from that string whose keys are the characters of the string and whose values are number of times that character is repeating.
#
#
# ***
# #### Sample Input/Output:
# ---
# **Sample 1**
#
# - Input: `Enter a string: AAABBCCCCC##**`
# - Output: `Characters with its count:  {'*': 2, 'C': 5, '#': 2, 'B': 2, 'A': 3}`
#
# ---
# **Sample 2**
#
# - Input: `Enter a string: ''`
# - Output: `Characters with its count: {}`
# ***

# %%
s = input('Enter a string: ')

char_count = dict()
#### Add your code here ####
for i in s:
    if i in char_count:
        char_count[i] += 1
    else:
        char_count[i] = 1

print('Characters with its count: ', char_count)
# Out:
# Characters with its count:  {'S': 1, 'a': 2, 'y': 1, 'n': 1}

# %% [markdown]
# ## Question 3 (25 Marks)

# %% [markdown]
# Write python codes for the following
#
# - In `Tesla` class write python code in the constructor to initialize the attributes of the class named as `model_name`, `max_speed`, `capacity` and `total_production`.
# - In `Bus` (derived class) write python code to inherit all the variables/methods of the `Tesla` class
# - Write code to print the allocated values for the instantiated `Bus` object

# %%
class Tesla:
    def __init__(self, model_name, max_speed, capacity, total_production):
        #### Add your code here ####
        self.model_name = model_name
        self.max_speed = max_speed
        self.capacity = capacity
        self.total_production = total_production

        def printDetails(self):
          print(self.model_name, self.max_speed, self.capacity, self.total_production)
        
class Bus(Tesla):
  #### Add your code here ####
  def __init__(self, model, speed, capacity, production):
    super().__init__(model, speed, capacity, production)

  def printDetails(self)

school_bus = Bus("School Volvo", 180, 45, 12000)

#### Add your code here ####
school_bus.printDetails()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/sayantanbasu/Downloads/Questions - Python Programming - Baseline Test - ACSE - IITM-1.ipynb Cell 12' in <cell line: 21>()
#      <a href='vscode-notebook-cell:/Users/sayantanbasu/Downloads/Questions%20-%20Python%20Programming%20-%20Baseline%20Test%20-%20ACSE%20-%20IITM-1.ipynb#ch0000011?line=17'>18</a> school_bus = Bus("School Volvo", 180, 45, 12000)
#      <a href='vscode-notebook-cell:/Users/sayantanbasu/Downloads/Questions%20-%20Python%20Programming%20-%20Baseline%20Test%20-%20ACSE%20-%20IITM-1.ipynb#ch0000011?line=19'>20</a> #### Add your code here ####
# ---> <a href='vscode-notebook-cell:/Users/sayantanbasu/Downloads/Questions%20-%20Python%20Programming%20-%20Baseline%20Test%20-%20ACSE%20-%20IITM-1.ipynb#ch0000011?line=20'>21</a> school_bus.printDetails()
#
# ...
